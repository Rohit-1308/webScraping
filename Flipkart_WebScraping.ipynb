# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np


headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
}
    
product_url = "https://www.flipkart.com/motorola-g32-satin-silver-128-gb/product-reviews/itm8e7224d29bfc6?pid=MOBGM2EHGUNGDDQR&lid=LSTMOBGM2EHGUNGDDQRKIBLDP&marketplace=FLIPKART"
    
reviews = []
page = 1
has_more_reviews = True

while has_more_reviews:
        url = f"{product_url}&page={page}"
        response = requests.get(url, headers=headers)
        soup = BeautifulSoup(response.content, 'html.parser')
        next_button = soup.find('a', {'class': "_1LKTO3"})
        print("next_button",next_button)

        review_containers = soup.find_all('div', {'class': '_1AtVbE'})

        for container in review_containers:
            try:
                rating_element = container.find('div', {'class': "_3LWZlK _1BLPMq"})
                rating = rating_element.text.strip() if rating_element else None
            
    
                review_text_element = container.find('div', {'class': 't-ZTKy'})
#                 print("review_text_element",review_text_element)
                review_text = review_text_element.text.strip() if review_text_element else None

                customer_name_element = container.find('p', {'class': '_2sc7ZR','class': '_2V5EHH'})
                customer_name = customer_name_element.text.strip() if customer_name_element else None


                comment_tags_elements = container.find('p', {'class': "_2-N8zT"})
                comment_tags = comment_tags_elements.text.strip() if comment_tags_elements else None
#                 for tag in comment_tags_elements:
#                     comment_tags.append(tag.text.strip())

                review = {
                    'rating': rating,
                    'review_text': review_text,
                    'comment_tags': comment_tags,
                    'customer_name': customer_name
                }
                reviews.append(review)

            except Exception as e:
                print('Error:', e)

        next_button = soup.find('a', {'class': "_1LKTO3"})
        has_more_reviews = has_more_reviews is not None
        if page > 5 :
            has_more_reviews=False
        page += 1



df = pd.DataFrame(reviews)
df=df.dropna()

# Filter out rows with empty or mischievous names
df['customer_name'] = np.where(df['customer_name'].str.len() > 0, df['customer_name'], "Not Available")

# Print unique customer names
unique_names = df['customer_name'].unique()
print(unique_names)

df.reset_index(drop=True, inplace=True)
display(df)
# Out:
# next_button <a class="_1LKTO3" href="/motorola-g32-satin-silver-128-gb/product-reviews/itm8e7224d29bfc6?pid=MOBGM2EHGUNGDDQR&amp;lid=LSTMOBGM2EHGUNGDDQRKIBLDP&amp;marketplace=FLIPKART&amp;page=2"><span>Next</span></a>
# next_button <a class="_1LKTO3" href="/motorola-g32-satin-silver-128-gb/product-reviews/itm8e7224d29bfc6?pid=MOBGM2EHGUNGDDQR&amp;lid=LSTMOBGM2EHGUNGDDQRKIBLDP&amp;marketplace=FLIPKART&amp;page=1"><span>Previous</span></a>
# next_button None
# next_button <a class="_1LKTO3" href="/motorola-g32-satin-silver-128-gb/product-reviews/itm8e7224d29bfc6?pid=MOBGM2EHGUNGDDQR&amp;lid=LSTMOBGM2EHGUNGDDQRKIBLDP&amp;marketplace=FLIPKART&amp;page=3"><span>Previous</span></a>
# next_button <a class="_1LKTO3" href="/motorola-g32-satin-silver-128-gb/product-reviews/itm8e7224d29bfc6?pid=MOBGM2EHGUNGDDQR&amp;lid=LSTMOBGM2EHGUNGDDQRKIBLDP&amp;marketplace=FLIPKART&amp;page=4"><span>Previous</span></a>
# next_button <a class="_1LKTO3" href="/motorola-g32-satin-silver-128-gb/product-reviews/itm8e7224d29bfc6?pid=MOBGM2EHGUNGDDQR&amp;lid=LSTMOBGM2EHGUNGDDQRKIBLDP&amp;marketplace=FLIPKART&amp;page=5"><span>Previous</span></a>
# ['Amit  Nirmal' 'Sudipta Haldar' 'Not Available' 'Rajeev  Kumar'
#  'RAVI  KUMAR' 'Santosh Nadda' 'kumar Rock' 'Rishi  Choudhury']
#    rating                                        review_text  \
# 0       5  Reviewing after 5 full days of use.Take a leap...
# 1       4  Battery service is good and charging time 45 t...
# 2       5  Very good in range very good quality products ...
# 3       4  Overall terrific phone in this price range .📸 ...
# 4       5  Moto g 32 good future quality, camera 📷 qualit...
# 5       5  Super smart phone at a very reasonable price.T...
# 6       4  Excellent 👌 to buy in these range with 8gb ram...
# 7       5  I used this mobile from past 5 days One word o...
# 8       5  Nice camera, pure Android support, very fast p...
# 9       5  After many years trying Stock Android without ...
# 10      4  Fast delivery    thanks flipkart,   ,,,but inf...
# 11      5  Good camera qualityNice 👍🙂Battery backup is go...
# 12      5            Very very happy 😊 nice productREAD MORE
# 13      5              very nice camera quality 5/5READ MORE
# 14      5  Very good product thankyou flipkart ⭐⭐⭐⭐⭐👌👌REA...
# 15      4            Good experience in this budgetREAD MORE
# 16      5                                      GoodREAD MORE
# 17      4                         Value for money 💰READ MORE
# 18      5  Good product and good quality so beautifulREAD...
# 19      5  Nice phone Nice DesignNice DisplayNice perform...
# 20      5                                      NiceREAD MORE
# 21      3  Mobile looks premium but performance is not mu...
# 22      4                              Best productREAD MORE
# 23      5               Good product value of moneyREAD MORE
# 24      5                                     SuperREAD MORE
# 25      5                   Best budget mobile motoREAD MORE
# 26      5                        Perfect allrounderREAD MORE
# 27      5                    Just like a good phoneREAD MORE
# 28      5  Purchased this phone yesterday on 03rd April 2...
# 29      5                           Vary nice phoneREAD MORE
# 30      5                               Nice cameraREAD MORE
# 31      5  Moto is always mota phone... Low budget excell...
# 32      5                               GOOD MOBILEREAD MORE
# 33      5                                      GoodREAD MORE
# 34      5                                Good phoneREAD MORE
# 35      5  Mind-blowing camera quality...extra ordinary m...
# 36      5      Nice product and camera very nice 👍👍READ MORE
# 37      5                                 ExcellentREAD MORE
# 38      5                                      NiceREAD MORE
# 39      5                              Best MobilesREAD MORE
# 40      5                            Perfect mobileREAD MORE
#
#                     comment_tags     customer_name
# 0                      Must buy!      Amit  Nirmal
# 1                    Pretty good    Sudipta Haldar
# 2                      Brilliant     Not Available
# 3                      Very Good     Not Available
# 4                      Just wow!     Not Available
# 5               Perfect product!     Not Available
# 6                    Good choice     Not Available
# 7          Mind-blowing purchase     Not Available
# 8            Best in the market!     Not Available
# 9              Worth every penny     Not Available
# 10                     Very Good     Not Available
# 11                     Wonderful     Not Available
# 12                        Super!     Rajeev  Kumar
# 13             Terrific purchase     Not Available
# 14                        Super!     Not Available
# 15                    Delightful       RAVI  KUMAR
# 16                Classy product     Not Available
# 17          Good quality product     Santosh Nadda
# 18                   Really Nice     Not Available
# 19           Best in the market!     Not Available
# 20                     Brilliant     Not Available
# 21                          Fair     Not Available
# 22                     Very Good     Not Available
# 23                       Awesome     Not Available
# 24                     Wonderful     Not Available
# 25                 Great product     Not Available
# 26                     Brilliant     Not Available
# 27              Perfect product!     Not Available
# 28  great deal and amazing phone     Not Available
# 29                       Awesome     Not Available
# 30                     Just wow!     Not Available
# 31                     Just wow!     Not Available
# 32                     Just wow!        kumar Rock
# 33                 Great product  Rishi  Choudhury
# 34                     Fabulous!     Not Available
# 35                     Wonderful     Not Available
# 36           Best in the market!     Not Available
# 37              Perfect product!     Not Available
# 38           Best in the market!     Not Available
# 39            Highly recommended     Not Available
# 40             Worth every penny     Not Available
